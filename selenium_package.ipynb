# %%
import pandas as pd 
import numpy as np
from draft_scrape import *

# %%
myteam = 'Team Whiting'

# %%
d = draft_monitor(myteam)
# driver.get(r"https://fantasy.espn.com/football/draft?leagueId=97522804&seasonId=2020&teamId=1&memberId={70782481-065A-4843-8A38-A138B0BADDA1}")

# %%
proj = pd.read_pickle('players.pkl')

# %% [markdown]
# Wait until draft room opens

# %%
d.configure_draft()

# %%
print(d.driver.title)
print(d.driver.current_url)

# %% [markdown]
# # Wait until the draft room opens

# %%
d.filter_picks(proj)
# Out:
#      playerId               player team position   age  exp  bye      points  \
# 0   2557997.0  Christian McCaffrey  CAR       RB  24.0  3.0  NaN  288.506696
# 1   2560968.0       Saquon Barkley  NYG       RB  23.0  2.0  NaN  270.049352
# 2   2555224.0      Ezekiel Elliott  DAL       RB  25.0  4.0  NaN  256.383828
# 3   2556075.0        Derrick Henry  TEN       RB  26.0  4.0  NaN  237.677703
# 4   2557991.0          Dalvin Cook  MIN       RB  25.0  3.0  NaN  231.766350
# ..        ...                  ...  ...      ...   ...  ...  ...         ...
# 27        NaN        Steelers D/ST  NaN      dst   NaN  NaN  NaN  129.800000
# 28        NaN          Texans D/ST  NaN      dst   NaN  NaN  NaN   75.660000
# 29        NaN          Titans D/ST  NaN      dst   NaN  NaN  NaN   83.140000
# 30        NaN         Vikings D/ST  NaN      dst   NaN  NaN  NaN  102.600000
# 31        NaN      Washington D/ST  NaN      dst   NaN  NaN  NaN   57.940000
#
#          lower       upper  ...       adp  auctionValue  adpDiff  cost  \
# 0   265.133189  302.219263  ...    1.9533        72.680  -0.9533  80.0
# 1   244.501192  297.133185  ...    2.0533        67.725  -0.0533  75.0
# 2   238.539195  278.376832  ...    3.5133        60.345  -0.5133  67.0
# 3   217.315797  246.640252  ...   16.5267        50.265 -12.5267  56.0
# 4   192.707601  247.833873  ...    7.7267        54.665  -2.7267  61.0
# ..         ...         ...  ...       ...           ...      ...   ...
# 27         NaN         NaN  ...   85.9000           NaN      NaN   NaN
# 28         NaN         NaN  ...  169.8000           NaN      NaN   NaN
# 29         NaN         NaN  ...  169.7000           NaN      NaN   NaN
# 30         NaN         NaN  ...  152.6000           NaN      NaN   NaN
# 31         NaN         NaN  ...  169.5000           NaN      NaN   NaN
#
#     ppdollar           espn_names  espn_id  picked  round  rpick
# 0   3.606334  Christian McCaffrey  3117251    True    1.0    1.0
# 1   3.600658       Saquon Barkley  3929630    True    1.0    2.0
# 2   3.826624      Ezekiel Elliott  3051392    True    1.0    3.0
# 3   4.244245        Derrick Henry  3043078    True    1.0    7.0
# 4   3.799448          Dalvin Cook  3116593    True    1.0    4.0
# ..       ...                  ...      ...     ...    ...    ...
# 27       NaN        Steelers D/ST      pit   False    NaN    NaN
# 28       NaN          Texans D/ST      hou   False    NaN    NaN
# 29       NaN          Titans D/ST      ten   False    NaN    NaN
# 30       NaN         Vikings D/ST      min   False    NaN    NaN
# 31       NaN      Washington D/ST      wsh   False    NaN    NaN
#
# [270 rows x 34 columns]
