# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = r"https://fantasyfootballcalculator.com/scenario-calculator"
params = lambda x,teams,scoring: {'format':scoring,
          'num_teams':teams,
          'draft_pick':x}

probabilities = {}
html = {}
for i in range(1,201):
    test = requests.get(url,params(i,10,'standard'))
    if test.status_code == 200:
        soup = BeautifulSoup(test.text, 'html.parser')
        html[i] = test
        probabilities[i] = soup.select("table")
    else:
        print(f"{i} failed")
        print(test.status_code)

df = pd.read_html(str(soup.find_all('table')[0]))

dfs = None
for k, table in probabilities.items():
    df = pd.read_html(str(table[0]))[0]
    df['pick'] = k
    if dfs is None:
        dfs = df
    else:
        dfs = dfs.append(df)

dfs

# %%
dfs.to_pickle('pick_prob.pkl')

# %%
pd.read_html(str(probabilities[1][0]))[0]
# Out:
#                     Name Pos Team  Bye       % Unnamed: 5
# 0    Christian McCaffrey  RB  CAR   13  100.0%          .
# 1         Saquon Barkley  RB  NYG   11  100.0%          .
# 2        Ezekiel Elliott  RB  DAL   10  100.0%          .
# 3          Derrick Henry  RB  TEN    7  100.0%          .
# 4           Alvin Kamara  RB   NO    6  100.0%          .
# ..                   ...  ..  ...  ...     ...        ...
# 185          Matt Prater  PK  DET    5  100.0%          .
# 186      Kaimi Fairbairn  PK  HOU    8  100.0%          .
# 187           Dan Bailey  PK  MIN    7  100.0%          .
# 188      Steven Hauschka  PK  BUF   11  100.0%          .
# 189          Jason Myers  PK  SEA    6  100.0%          .
#
# [190 rows x 6 columns]

# %%
probabilities[200][1]
# Out:
# <tr class="RB">
# <td>Christian McCaffrey</td>
# <td>RB</td>
# <td>CAR</td>
# <td>13</td>
# <td class="text-right">0.0%</td>
# <td class="align-middle" style="background-color: #FFF; border:0px; margin:0px; padding:0px; padding-left: 1px;">
# <span style="padding:0px;margin:0px;color:white;display:block;background-color:white;width: 0.0px;">.</span>
# </td>
# </tr>

# %%
test.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(test.text, 'html.parser')

# %%
soup.select('.table')
# Out:
# [<table class="table" style="max-width: 70%;">
#  <tr>
#  <th>Name</th><th>Pos</th><th>Team</th><th>Bye</th><th>%</th>
#  </tr>
#  <tr class="RB">
#  <td>Christian McCaffrey</td>
#  <td>RB</td>
#  <td>CAR</td>
#  <td>13</td>
#  <td class="text-right">0.0%</td>
#  <td class="align-middle" style="background-color: #FFF; border:0px; margin:0px; padding:0px; padding-left: 1px;">
#  <span style="padding:0px;margin:0px;color:white;display:block;background-color:white;width: 0.0px;">.</span>
#  </td>
#  </tr>
#  <tr class="RB">
#  <td>Saquon Barkley</td>
#  <td>RB</td>
#  <td>NYG</td>
#  <td>11</td>
#  <td class="text-right">0.0%</td>
#  <td class="align-middle" style="background-color: #FFF; border:0px; margin:0px; padding:0px; padding-left: 1px;">
#  <span style="padding:0px;margin:0px;color:white;display:block;background-color:white;width: 0.0px;">.</span>
#  </td>
#  </tr>
#  <tr class="RB">
#  <td>Ezekiel Elliott</td>
#  <td>RB</td>
#  <td>DAL</td>
#  <td>10</td>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="FLVzGPDDjTEJeyGTTRMk4SM3x2nOKmmy9qnMyIRd_G0" name="google-site-verification">
#    <meta content="width=device-width, initial-scale=1" name="viewport"/>
#    <meta content="Find where players will fall to you in your fantasy football drafts. Use the Scenario Calculator to optimize your draft strategy." name="description"/>
#    <meta content="#1C8E3D" name="theme-color"/>
#    <title>
#     Scenario Calculator
#    </title>
#    <style type="text/css">
#     /* Make sure this is inline as images really screw up the page */
#     .img-fluid {
#       max-width: 100%;
#       height: auto;
#     }
#     .img-responsive {
#       max-width: 100%;
#       height: auto;
#     }
#
#     /* Device detection */
#     .visible-android {
#       display:none;
#       }
#       .visible-ios {
#         display:none;
#         }
# ...
