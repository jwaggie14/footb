# %% [markdown]
# # Start Up

# %% [markdown]
# Run the cells below. They will open a browser window through selenium. (check your open windows if you don't notice it. It will be a firefox page with an orange url bar.)
#
# Log into your ESPN account and navigate to the draft.
#
# Make sure to keep everything in a single tab. Do not open links as new windows, do not open links as new tabs. This should be the default behavior if you just click on things normally (but no promises - this is hacked together at best...)

# %% [markdown]
# ### Updating the probabilities
#
# The default score/pick probability info is for 10 team, standard (non-ppr) scoring.
#
# You can update the probabilities with different parameters ```grandmaster.create_prob_pickle(teams, outputname, mapping_path, scoring, outputpath)``` where teams is the number of teams in your league, and scoring is one of these four entries:
#  - 'standard'
#  - 'ppr'
#  - 'half-ppr'
#  - '2qb
#
# The other parameters deal with file mappings.
#
# Follow this link to see the source data [Fantasy Football Calculator](https://fantasyfootballcalculator.com/scenario-calculator)

# %% [markdown]
# ### Updating/Changing the Projections
#
# You can call ```grandmaster.process_projections(projection_path, idmap_path, output_path)```
# to update or change the projections. ```projection_path``` is the direction to the projection files. I use [fantasyfootballanalytics.net](https://www.fantasyfootballanalytics.net)
#
# You can use any source of projections as long as you can map them to the ESPN IDs.
#
# Required columns:
#  - 'position'
#  - 'player'
#  - 'points'
#  - 'adp'
#
# This needs more development, specifically:
#  - mapping tables to cross-reference all the different sources to some sort of master ID
#  - It would also be useful to map the player IDs to the different providers.
#  - making the column naming more flexible
#
#
#  # Current Use.
#  I've put together a rough GUI using widgets. Follow the instructions [here](https://ipywidgets.readthedocs.io/en/latest/user_install.html) to install and enable them.
#
#  Alternatively, there is another notebook in the git repo labeled No GUI or something that just calls the functions directly.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import pandas as pd 
import numpy as np
import grandmaster as gm

# %%
from yahoo_oauth import OAuth2
oauth = OAuth2(None, None, from_file='oauth.json')
if not oauth.token_is_valid():
    oauth.refresh_access_token()
# Out:
# [2020-09-01 06:48:13,223 DEBUG] [yahoo_oauth.oauth.__init__] Checking
# [2020-09-01 06:48:13,304 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 850.9627220630646
# [2020-09-01 06:48:13,305 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# [2020-09-01 06:48:13,368 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 851.0275483131409
# [2020-09-01 06:48:13,369 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID

# %% [markdown]
# single resource format
# https://fantasysports.yahooapis.com/fantasy/v2/{resource/{resource_key}
#
# collection
# https://fantasysports.yahooapis.com/fantasy/v2/{collection};{resource}_keys={resource_key1},{resource_key2}
#
# 223.l.431

# %%
r = oauth.session.get('https://fantasysports.yahooapis.com/fantasy/v2/league/pnfl.l.342412')

# %%
oauth.token_is_valid()
# Out:
# [2020-09-01 06:58:04,804 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 1442.4631724357605
# [2020-09-01 06:58:04,805 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# True

# %%
r.status_code
# Out:
# 400

# %%
import xml.etree.ElementTree as ET 
import re
import csv

# %%
r = oauth.session.get('https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l.978311/teams;team_keys=399.l.978311.t.5')

# %%
xmlstring = r.text
xmlstring = re.sub(' xmlns="[^"]+"', '', xmlstring, count=1)
root = ET.fromstring(xmlstring)

# %%
print(r.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <fantasy_content xml:lang="en-US" yahoo:uri="http://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l.978311/teams;team_keys=399.l.978311.t.5" time="32.719850540161ms" copyright="Data provided by Yahoo! and STATS, LLC" refresh_rate="60" xmlns:yahoo="http://www.yahooapis.com/v1/base.rng" xmlns="http://fantasysports.yahooapis.com/fantasy/v2/base.rng">
#  <league>
#   <league_key>399.l.978311</league_key>
#   <league_id>978311</league_id>
#   <name>Yahoo Best Ball 978311</name>
#   <url>https://football.fantasysports.yahoo.com/f1/978311</url>
#   <logo_url>https://s.yimg.com/cv/api/default/20180206/default-league-logo@2x.png</logo_url>
#   <draft_status>draft</draft_status>
#   <num_teams>10</num_teams>
#   <edit_key>1</edit_key>
#   <weekly_deadline/>
#   <league_update_timestamp/>
#   <scoring_type>point</scoring_type>
#   <league_type>public</league_type>
#   <renew/>
#   <renewed/>
#   <iris_group_chat_id/>
#   <allow_add_to_dl_extra_pos>0</allow_add_to_dl_extra_pos>
#   <is_pro_league>0</is_pro_league>
#   <is_cash_league>0</is_cash_league>
#   <current_week>1</current_week>
#   <start_week>1</start_week>
#   <start_date>2020-09-10</start_date>
#   <end_week>16</end_week>
#   <end_date>2020-12-28</end_date>
#   <game_code>nfl</game_code>
#   <season>2020</season>
#   <teams count="1">
#    <team>
#     <team_key>399.l.978311.t.5</team_key>
#     <team_id>5</team_id>
#     <name>James's Notable Team</name>
#     <is_owned_by_current_login>1</is_owned_by_current_login>
#     <url>https://football.fantasysports.yahoo.com/f1/978311/5</url>
#     <team_logos>
#      <team_logo>
#       <size>large</size>
#       <url>https://s.yimg.com/cv/apiv2/default/nfl/nfl_12_j.png</url>
#      </team_logo>
#     </team_logos>
#     <waiver_priority/>
#     <number_of_moves>0</number_of_moves>
#     <number_of_trades>0</number_of_trades>
#     <roster_adds>
#      <coverage_type>week</coverage_type>
#      <coverage_value>1</coverage_value>
#      <value>0</value>
#     </roster_adds>
#     <league_scoring_type>point</league_scoring_type>
#     <draft_position>4</draft_position>
#     <has_draft_grade>0</has_draft_grade>
#     <managers>
#      <manager>
#       <manager_id>5</manager_id>
#       <nickname>James</nickname>
#       <guid>XQ4DZLNVCXCPTZKXLOHWYBNKFA</guid>
#       <is_current_login>1</is_current_login>
#       <image_url>https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg</image_url>
#       <experience>ROOKIE</experience>
#      </manager>
#     </managers>
#    </team>
#   </teams>
#  </league>
# </fantasy_content>
# <!-- fantasy-sports-api- -public-production-bf1-6765457769-bbn2j Tue Sep  1 12:28:35 UTC 2020 -->

# %%
url2 = f"https://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l.978311/teams;team_keys={', '.join(teams)}/players"

# %%
r2 = oauth.session.get(url2)

# %%
print(r.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <fantasy_content xml:lang="en-US" yahoo:uri="http://fantasysports.yahooapis.com/fantasy/v2/league/nfl.l.978311/teams" time="72.375774383545ms" copyright="Data provided by Yahoo! and STATS, LLC" refresh_rate="60" xmlns:yahoo="http://www.yahooapis.com/v1/base.rng" xmlns="http://fantasysports.yahooapis.com/fantasy/v2/base.rng">
#  <league>
#   <league_key>399.l.978311</league_key>
#   <league_id>978311</league_id>
#   <name>Yahoo Best Ball 978311</name>
#   <url>https://football.fantasysports.yahoo.com/f1/978311</url>
#   <logo_url>https://s.yimg.com/cv/api/default/20180206/default-league-logo@2x.png</logo_url>
#   <draft_status>draft</draft_status>
#   <num_teams>10</num_teams>
#   <edit_key>1</edit_key>
#   <weekly_deadline/>
#   <league_update_timestamp/>
#   <scoring_type>point</scoring_type>
#   <league_type>public</league_type>
#   <renew/>
#   <renewed/>
#   <iris_group_chat_id/>
#   <allow_add_to_dl_extra_pos>0</allow_add_to_dl_extra_pos>
#   <is_pro_league>0</is_pro_league>
#   <is_cash_league>0</is_cash_league>
#   <current_week>1</current_week>
#   <start_week>1</start_week>
#   <start_date>2020-09-10</start_date>
#   <end_week>16</end_week>
#   <end_date>2020-12-28</end_date>
#   <game_code>nfl</game_code>
#   <season>2020</season>
#   <teams count="10">
#    <team>
#     <team_key>399.l.978311.t.1</team_key>
#     <team_id>1</team_id>
#     <name>Dan's Neat Team</name>
#     <url>https://football.fantasysports.yahoo.com/f1/978311/1</url>
#     <team_logos>
#      <team_logo>
#       <size>large</size>
#       <url>https://s.yimg.com/cv/apiv2/default/nfl/nfl_6_d.png</url>
#      </team_logo>
#     </team_logos>
#     <waiver_priority/>
#     <number_of_moves>0</number_of_moves>
#     <number_of_trades>0</number_of_trades>
#     <roster_adds>
#      <coverage_type>week</coverage_type>
#      <coverage_value>1</coverage_value>
#      <value>0</value>
#     </roster_adds>
#     <league_scoring_type>point</league_scoring_type>
#     <draft_position>9</draft_position>
#     <has_draft_grade>0</has_draft_grade>
#     <managers>
#      <manager>
#       <manager_id>1</manager_id>
#       <nickname>Dan</nickname>
#       <guid>LBAVGDIYCY77RIJPN25IAGKORM</guid>
#       <image_url>https://s.yimg.com/ag/images/4565/38381799165_c26842_64sq.jpg</image_url>
#       <experience>ROOKIE</experience>
#      </manager>
#     </managers>
#    </team>
#    <team>
#     <team_key>399.l.978311.t.2</team_key>
#     <team_id>2</team_id>
#     <name>Gary's Quality Team</name>
#     <url>https://football.fantasysports.yahoo.com/f1/978311/2</url>
#     <team_logos>
#      <team_logo>
#       <size>large</size>
#       <url>https://s.yimg.com/cv/apiv2/default/nfl/nfl_5_g.png</url>
#      </team_logo>
#     </team_logos>
#     <waiver_priority/>
#     <number_of_moves>0</number_of_moves>
#     <number_of_trades>0</number_of_trades>
#     <roster_adds>
#      <coverage_type>week</coverage_type>
#      <coverage_value>1</coverage_value>
#      <value>0</value>
#     </roster_adds>
#     <league_scoring_type>point</league_scoring_type>
#     <draft_position>8</draft_position>
#     <has_draft_grade>0</has_draft_grade>
#     <managers>
#      <manager>
#       <manager_id>2</manager_id>
#       <nickname>Gary</nickname>
#       <guid>A22MCAGONCPQLUAWTB2IXM6ZRI</guid>
#       <image_url>https://s.yimg.com/ag/images/4540/37992877420_8f2b2e_64sq.jpg</image_url>
#       <experience>ROOKIE</experience>
#      </manager>
#     </managers>
#    </team>
#    <team>
#     <team_key>399.l.978311.t.3</team_key>
#     <team_id>3</team_id>
#     <name>KEN's Team</name>
#     <url>https://football.fantasysports.yahoo.com/f1/978311/3</url>
#     <team_logos>
#      <team_logo>
#       <size>large</size>
#       <url>https://s.yimg.com/cv/apiv2/default/nfl/nfl_11_k.png</url>
#      </team_logo>
#     </team_logos>
#     <waiver_priority/>
#     <number_of_moves>0</number_of_moves>
#     <number_of_trades>0</number_of_trades>
#     <roster_adds>
#      <coverage_type>week</coverage_type>
#      <coverage_value>1</coverage_value>
#      <value>0</value>
#     </roster_adds>
#     <league_scoring_type>point</league_scoring_type>
#     <draft_position>1</draft_position>
#     <has_draft_grade>0</has_draft_grade>
#     <managers>
#      <manager>
#       <manager_id>3</manager_id>
#       <nickname>KEN</nickname>
#       <guid>EO73ZW3CJEK3FWDTANF6FK4MIA</guid>
#       <image_url>https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg</image_url>
#       <experience>ROOKIE</experience>
#      </manager>
#     </managers>
#    </team>
#    <team>
#     <team_key>399.l.978311.t.4</team_key>
#     <team_id>4</team_id>
#     <name>Daniel Glickberg</name>
#     <url>https://football.fantasysports.yahoo.com/f1/978311/4</url>
#     <team_logos>
#      <team_logo>
#       <size>large</size>
#       <url>https://s.yimg.com/cv/apiv2/default/nfl/nfl_11_d.png</url>
#      </team_logo>
#     </team_logos>
#     <waiver_priority/>
#     <number_of_moves>0</number_of_moves>
#     <number_of_trades>0</number_of_trades>
#     <roster_adds>
#      <coverage_type>week</coverage_type>
#      <coverage_value>1</coverage_value>
#      <value>0</value>
#     </roster_adds>
#     <league_scoring_type>point</league_scoring_type>
#     <draft_position>3</draft_position>
#     <has_draft_grade>0</has_draft_grade>
#     <managers>
#      <manager>
#       <manager_id>4</manager_id>
#       <nickname>Daniel Glickberg</nickname>
#       <guid>WTBT4XRXGB23UGJ5ACISDIHK7Y</guid>
#       <image_url>https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg</image_url>
#       <experience>ROOKIE</experience>
#      </manager>
#     </managers>
#    </team>
#    <team>
#     <team_key>399.l.978311.t.5</team_key>
#     <team_id>5</team_id>
#     <name>James's Notable Team</name>
#     <is_owned_by_current_login>1</is_owned_by_current_login>
#     <url>https://football.fantasysports.yahoo.com/f1/978311/5</url>
#     <team_logos>
#      <team_logo>
#       <size>large</size>
#       <url>https://s.yimg.com/cv/apiv2/default/nfl/nfl_12_j.png</url>
#      </team_logo>
#     </team_logos>
#     <waiver_priority/>
#     <number_of_moves>0</number_of_moves>
#     <number_of_trades>0</number_of_trades>
#     <roster_adds>
#      <coverage_type>week</coverage_type>
#      <coverage_value>1</coverage_value>
#      <value>0</value>
#     </roster_adds>
#     <league_scoring_type>point</league_scoring_type>
#     <draft_position>4</draft_position>
#     <has_draft_grade>0</has_draft_grade>
#     <managers>
#      <manager>
#       <manager_id>5</manager_id>
#       <nickname>James</nickname>
#       <guid>XQ4DZLNVCXCPTZKXLOHWYBNKFA</guid>
#       <is_current_login>1</is_current_login>
#       <image_url>https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg</image_url>
#       <experience>ROOKIE</experience>
#      </manager>
#     </managers>
#    </team>
#    <team>
#     <team_key>399.l.978311.t.6</team_key>
#     <team_id>6</team_id>
#     <name>matt's Official Team</name>
#     <url>https://football.fantasysports.yahoo.com/f1/978311/6</url>
#     <team_logos>
#      <team_logo>
#       <size>large</size>
#       <url>https://s.yimg.com/cv/apiv2/default/nfl/nfl_5_m.png</url>
#      </team_logo>
#     </team_logos>
#     <waiver_priority/>
#     <number_of_moves>0</number_of_moves>
#     <number_of_trades>0</number_of_trades>
#     <roster_adds>
#      <coverage_type>week</coverage_type>
#      <coverage_value>1</coverage_value>
#      <value>0</value>
#     </roster_adds>
#     <league_scoring_type>point</league_scoring_type>
#     <draft_position>7</draft_position>
#     <has_draft_grade>0</has_draft_grade>
#     <managers>
#      <manager>
#       <manager_id>6</manager_id>
#       <nickname>matt</nickname>
#       <guid>OKNVRQHRLFJHRBCOYLIR4WJ3QY</guid>
#       <image_url>https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg</image_url>
#       <experience>ROOKIE</experience>
#      </manager>
#     </managers>
#    </team>
#    <team>
#     <team_key>399.l.978311.t.7</team_key>
#     <team_id>7</team_id>
#     <name>asda's Team</name>
#     <url>https://football.fantasysports.yahoo.com/f1/978311/7</url>
#     <team_logos>
#      <team_logo>
#       <size>large</size>
#       <url>https://s.yimg.com/cv/apiv2/default/nfl/nfl_11_a.png</url>
#      </team_logo>
#     </team_logos>
#     <waiver_priority/>
#     <number_of_moves>0</number_of_moves>
#     <number_of_trades>0</number_of_trades>
#     <roster_adds>
#      <coverage_type>week</coverage_type>
#      <coverage_value>1</coverage_value>
#      <value>0</value>
#     </roster_adds>
#     <league_scoring_type>point</league_scoring_type>
#     <draft_position>5</draft_position>
#     <has_draft_grade>0</has_draft_grade>
#     <managers>
#      <manager>
#       <manager_id>7</manager_id>
#       <nickname>asda</nickname>
#       <guid>J2SYHRFWRWZYK7TUE6C6NYG7SY</guid>
#       <image_url>https://s.yimg.com/ag/images/4509/38052228104_1ddb92_64sq.jpg</image_url>
#       <experience>ROOKIE</experience>
#      </manager>
#     </managers>
#    </team>
#    <team>
#     <team_key>399.l.978311.t.8</team_key>
#     <team_id>8</team_id>
#     <name>ECC's Team</name>
#     <url>https://football.fantasysports.yahoo.com/f1/978311/8</url>
#     <team_logos>
#      <team_logo>
#       <size>large</size>
#       <url>https://s.yimg.com/cv/apiv2/default/nfl/nfl_12_e.png</url>
#      </team_logo>
#     </team_logos>
#     <waiver_priority/>
#     <number_of_moves>0</number_of_moves>
#     <number_of_trades>0</number_of_trades>
#     <roster_adds>
#      <coverage_type>week</coverage_type>
#      <coverage_value>1</coverage_value>
#      <value>0</value>
#     </roster_adds>
#     <league_scoring_type>point</league_scoring_type>
#     <draft_position>10</draft_position>
#     <has_draft_grade>0</has_draft_grade>
#     <managers>
#      <manager>
#       <manager_id>8</manager_id>
#       <nickname>ECC</nickname>
#       <guid>B32VR4HHGTWCL2KNGDT47KRTK4</guid>
#       <image_url>https://s.yimg.com/ag/images/4555/38722385596_d339cf_64sq.jpg</image_url>
#       <experience>ROOKIE</experience>
#      </manager>
#     </managers>
#    </team>
#    <team>
#     <team_key>399.l.978311.t.9</team_key>
#     <team_id>9</team_id>
#     <name>Joshua's Bold Team</name>
#     <url>https://football.fantasysports.yahoo.com/f1/978311/9</url>
#     <team_logos>
#      <team_logo>
#       <size>large</size>
#       <url>https://s.yimg.com/cv/apiv2/default/nfl/nfl_12_j.png</url>
#      </team_logo>
#     </team_logos>
#     <waiver_priority/>
#     <number_of_moves>0</number_of_moves>
#     <number_of_trades>0</number_of_trades>
#     <roster_adds>
#      <coverage_type>week</coverage_type>
#      <coverage_value>1</coverage_value>
#      <value>0</value>
#     </roster_adds>
#     <league_scoring_type>point</league_scoring_type>
#     <draft_position>6</draft_position>
#     <has_draft_grade>0</has_draft_grade>
#     <managers>
#      <manager>
#       <manager_id>9</manager_id>
#       <nickname>Joshua</nickname>
#       <guid>JBBLFSUUZPZLYNMSRI3ZLZSRQM</guid>
#       <image_url>https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg</image_url>
#       <experience>ROOKIE</experience>
#      </manager>
#     </managers>
#    </team>
#    <team>
#     <team_key>399.l.978311.t.10</team_key>
#     <team_id>10</team_id>
#     <name>Gabe's Great Team</name>
#     <url>https://football.fantasysports.yahoo.com/f1/978311/10</url>
#     <team_logos>
#      <team_logo>
#       <size>large</size>
#       <url>https://s.yimg.com/cv/apiv2/default/nfl/nfl_2_g.png</url>
#      </team_logo>
#     </team_logos>
#     <waiver_priority/>
#     <number_of_moves>0</number_of_moves>
#     <number_of_trades>0</number_of_trades>
#     <roster_adds>
#      <coverage_type>week</coverage_type>
#      <coverage_value>1</coverage_value>
#      <value>0</value>
#     </roster_adds>
#     <league_scoring_type>point</league_scoring_type>
#     <draft_position>2</draft_position>
#     <has_draft_grade>0</has_draft_grade>
#     <managers>
#      <manager>
#       <manager_id>10</manager_id>
#       <nickname>Gabe</nickname>
#       <guid>FLLORHGT45JTKOEXVA2YHHBD5U</guid>
#       <image_url>https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg</image_url>
#       <experience>ROOKIE</experience>
#      </manager>
#     </managers>
#    </team>
#   </teams>
#  </league>
# </fantasy_content>
# <!-- fantasy-sports-api- -public-production-bf1-6765457769-55jmc Tue Sep  1 12:19:14 UTC 2020 -->

# %%
teams = []
for child in root.iter('team_key'):
    teams.append(child.text)

# %%
str(teams)
# Out:
# "['399.l.978311.t.1', '399.l.978311.t.2', '399.l.978311.t.3', '399.l.978311.t.4', '399.l.978311.t.5', '399.l.978311.t.6', '399.l.978311.t.7', '399.l.978311.t.8', '399.l.978311.t.9', '399.l.978311.t.10']"

# %%
for team_key in root.findall('./leagues/league/standings/teams/team'):
    value = team_key
    print(1)

# %%
978311

# %%
url = "https://fantasysports.yahooapis.com/fantasy/v2/leagues;league_keys=
​	79.l.******, 101.l.******, 124.l.******, 153.l.******, 
​	175.l.******, 199.l.******, 222.l.******, 242.l.******, 
​	257.l.******, 273.l.******, 314.l.******, 331.l.******, 
​	348.l.******, 359.l.******, 371.l.******/standings"
r = oauth.session.get(url)

# %%
mapper = pd.read_json('nfl.json')

# %%
mapper.T[mapper.T['position'] == 'DEF']
# Out:
#     position search_rank practice_participation birth_state search_full_name  \
# WAS      DEF         NaN                    NaN         NaN              NaN
# ARI      DEF         NaN                    NaN         NaN              NaN
# ATL      DEF         NaN                    NaN         NaN              NaN
# TEN      DEF         NaN                    NaN         NaN              NaN
# LAR      DEF         NaN                    NaN         NaN              NaN
# PIT      DEF         NaN                    NaN         NaN              NaN
# NE       DEF         NaN                    NaN         NaN              NaN
# CLE      DEF         NaN                    NaN         NaN              NaN
# SEA      DEF         NaN                    NaN         NaN              NaN
# HOU      DEF         NaN                    NaN         NaN              NaN
# LV       DEF         NaN                    NaN         NaN              NaN
# LAC      DEF         NaN                    NaN         NaN              NaN
# BAL      DEF         NaN                    NaN         NaN              NaN
# PHI      DEF         NaN                    NaN         NaN              NaN
# JAX      DEF         NaN                    NaN         NaN              NaN
# GB       DEF         NaN                    NaN         NaN              NaN
# NYG      DEF         NaN                    NaN         NaN              NaN
# IND      DEF         NaN                    NaN         NaN              NaN
# NYJ      DEF         NaN                    NaN         NaN              NaN
# CIN      DEF         NaN                    NaN         NaN              NaN
# MIA      DEF         NaN                    NaN         NaN              NaN
# CAR      DEF         NaN                    NaN         NaN              NaN
# NO       DEF         NaN                    NaN         NaN              NaN
# SF       DEF         NaN                    NaN         NaN              NaN
# DAL      DEF         NaN                    NaN         NaN              NaN
# DEN      DEF         NaN                    NaN         NaN              NaN
# TB       DEF         NaN                    NaN         NaN              NaN
# CHI      DEF         NaN                    NaN         NaN              NaN
# KC       DEF         NaN                    NaN         NaN              NaN
# BUF      DEF         NaN                    NaN         NaN              NaN
# MIN      DEF         NaN                    NaN         NaN              NaN
# DET      DEF         NaN                    NaN         NaN              NaN
#
#     injury_status stats_id player_id practice_description status  ... weight  \
# WAS           NaN      NaN       WAS                  NaN    NaN  ...    NaN
# ARI           NaN      NaN       ARI                  NaN    NaN  ...    NaN
# ATL           NaN      NaN       ATL                  NaN    NaN  ...    NaN
# TEN           NaN      NaN       TEN                  NaN    NaN  ...    NaN
# LAR           NaN      NaN       LAR                  NaN    NaN  ...    NaN
# PIT           NaN      NaN       PIT                  NaN    NaN  ...    NaN
# NE            NaN      NaN        NE                  NaN    NaN  ...    NaN
# CLE           NaN      NaN       CLE                  NaN    NaN  ...    NaN
# SEA           NaN      NaN       SEA                  NaN    NaN  ...    NaN
# HOU           NaN      NaN       HOU                  NaN    NaN  ...    NaN
# LV            NaN      NaN        LV                  NaN    NaN  ...    NaN
# LAC           NaN      NaN       LAC                  NaN    NaN  ...    NaN
# BAL           NaN      NaN       BAL                  NaN    NaN  ...    NaN
# PHI           NaN      NaN       PHI                  NaN    NaN  ...    NaN
# JAX           NaN      NaN       JAX                  NaN    NaN  ...    NaN
# GB            NaN      NaN        GB                  NaN    NaN  ...    NaN
# NYG           NaN      NaN       NYG                  NaN    NaN  ...    NaN
# IND           NaN      NaN       IND                  NaN    NaN  ...    NaN
# NYJ           NaN      NaN       NYJ                  NaN    NaN  ...    NaN
# CIN           NaN      NaN       CIN                  NaN    NaN  ...    NaN
# MIA           NaN      NaN       MIA                  NaN    NaN  ...    NaN
# CAR           NaN      NaN       CAR                  NaN    NaN  ...    NaN
# NO            NaN      NaN        NO                  NaN    NaN  ...    NaN
# SF            NaN      NaN        SF                  NaN    NaN  ...    NaN
# DAL           NaN      NaN       DAL                  NaN    NaN  ...    NaN
# DEN           NaN      NaN       DEN                  NaN    NaN  ...    NaN
# TB            NaN      NaN        TB                  NaN    NaN  ...    NaN
# CHI           NaN      NaN       CHI                  NaN    NaN  ...    NaN
# KC            NaN      NaN        KC                  NaN    NaN  ...    NaN
# BUF           NaN      NaN       BUF                  NaN    NaN  ...    NaN
# MIN           NaN      NaN       MIN                  NaN    NaN  ...    NaN
# DET           NaN      NaN       DET                  NaN    NaN  ...    NaN
#
#     injury_body_part     first_name sportradar_id years_exp sport  \
# WAS              NaN     Washington           NaN       NaN   nfl
# ARI              NaN        Arizona           NaN       NaN   nfl
# ATL              NaN        Atlanta           NaN       NaN   nfl
# TEN              NaN      Tennessee           NaN       NaN   nfl
# LAR              NaN    Los Angeles           NaN       NaN   nfl
# PIT              NaN     Pittsburgh           NaN       NaN   nfl
# NE               NaN    New England           NaN       NaN   nfl
# CLE              NaN      Cleveland           NaN       NaN   nfl
# SEA              NaN        Seattle           NaN       NaN   nfl
# HOU              NaN        Houston           NaN       NaN   nfl
# LV               NaN      Las Vegas           NaN       NaN   nfl
# LAC              NaN    Los Angeles           NaN       NaN   nfl
# BAL              NaN      Baltimore           NaN       NaN   nfl
# PHI              NaN   Philadelphia           NaN       NaN   nfl
# JAX              NaN   Jacksonville           NaN       NaN   nfl
# GB               NaN      Green Bay           NaN       NaN   nfl
# NYG              NaN       New York           NaN       NaN   nfl
# IND              NaN   Indianapolis           NaN       NaN   nfl
# NYJ              NaN       New York           NaN       NaN   nfl
# CIN              NaN     Cincinnati           NaN       NaN   nfl
# MIA              NaN          Miami           NaN       NaN   nfl
# CAR              NaN       Carolina           NaN       NaN   nfl
# NO               NaN    New Orleans           NaN       NaN   nfl
# SF               NaN  San Francisco           NaN       NaN   nfl
# DAL              NaN         Dallas           NaN       NaN   nfl
# DEN              NaN         Denver           NaN       NaN   nfl
# TB               NaN      Tampa Bay           NaN       NaN   nfl
# CHI              NaN        Chicago           NaN       NaN   nfl
# KC               NaN    Kansas City           NaN       NaN   nfl
# BUF              NaN        Buffalo           NaN       NaN   nfl
# MIN              NaN      Minnesota           NaN       NaN   nfl
# DET              NaN        Detroit           NaN       NaN   nfl
#
#     search_first_name birth_date team birth_city
# WAS               NaN        NaN  WAS        NaN
# ARI               NaN        NaN  ARI        NaN
# ATL               NaN        NaN  ATL        NaN
# TEN               NaN        NaN  TEN        NaN
# LAR               NaN        NaN  LAR        NaN
# PIT               NaN        NaN  PIT        NaN
# NE                NaN        NaN   NE        NaN
# CLE               NaN        NaN  CLE        NaN
# SEA               NaN        NaN  SEA        NaN
# HOU               NaN        NaN  HOU        NaN
# LV                NaN        NaN   LV        NaN
# LAC               NaN        NaN  LAC        NaN
# BAL               NaN        NaN  BAL        NaN
# PHI               NaN        NaN  PHI        NaN
# JAX               NaN        NaN  JAX        NaN
# GB                NaN        NaN   GB        NaN
# NYG               NaN        NaN  NYG        NaN
# IND               NaN        NaN  IND        NaN
# NYJ               NaN        NaN  NYJ        NaN
# CIN               NaN        NaN  CIN        NaN
# MIA               NaN        NaN  MIA        NaN
# CAR               NaN        NaN  CAR        NaN
# NO                NaN        NaN   NO        NaN
# SF                NaN        NaN   SF        NaN
# DAL               NaN        NaN  DAL        NaN
# DEN               NaN        NaN  DEN        NaN
# TB                NaN        NaN   TB        NaN
# CHI               NaN        NaN  CHI        NaN
# KC                NaN        NaN   KC        NaN
# BUF               NaN        NaN  BUF        NaN
# MIN               NaN        NaN  MIN        NaN
# DET               NaN        NaN  DET        NaN
#
# [32 rows x 45 columns]

# %%
mapper = mapper.fillna(np.nan)

# %%
mapper = mapper.T.dropna(subset=['espn_id'])

# %%
mapper.position.unique()
# Out:
# array(['OT', 'DT', 'NT', 'QB', 'ILB', 'TE', 'P', 'C', 'LB', 'DE', 'FS',
#        'WR', nan, 'CB', 'RB', 'K', 'OLB', 'LS', 'G', 'FB', 'SS', 'S',
#        'DL', 'DB', 'OL'], dtype=object)

# %%
mapper.columns
# Out:
# Index(['position', 'search_rank', 'practice_participation', 'birth_state',
#        'search_full_name', 'injury_status', 'stats_id', 'player_id',
#        'practice_description', 'status', 'yahoo_id', 'espn_id', 'metadata',
#        'pandascore_id', 'depth_chart_order', 'college', 'full_name', 'gsis_id',
#        'number', 'rotowire_id', 'injury_start_date', 'active', 'hashtag',
#        'injury_notes', 'birth_country', 'height', 'depth_chart_position',
#        'news_updated', 'fantasy_data_id', 'rotoworld_id', 'search_last_name',
#        'age', 'high_school', 'fantasy_positions', 'last_name', 'weight',
#        'injury_body_part', 'first_name', 'sportradar_id', 'years_exp', 'sport',
#        'search_first_name', 'birth_date', 'team', 'birth_city'],
#       dtype='object')

# %%
mapper[mapper['position'].isin(['QB','TE','WR','RB','K'])][['player_id','full_name','yahoo_id','espn_id','rotowire_id','fantasy_data_id','rotoworld_id','sportradar_id','stats_id','search_first_name','search_last_name','birth_date']]
# Out:
#      player_id         full_name yahoo_id  espn_id rotowire_id  \
# 5870      5870      Daniel Jones    31838  3917792       13491
# 1347      1347       Chris Gragg    26845    15940        8788
# 3396      3396     Charone Peake    29475  2576498       11001
# 6343      6343     Manny Wilkins    32282  3128814       13968
# 3199      3199    Michael Thomas    29281  2976316       10759
# ...        ...               ...      ...      ...         ...
# 1650      1650  Cameron Marshall    27250    16370        8847
# 2912      2912    Joshua Stangby    28829  3893002       10783
# 1195      1195       Doug Martin    25741    14885        8058
# 3914      3914    Dobson Collins     9668    12913        6951
# 5135      5135   Saeed Blacknall    31479  3116155       13028
#
#      fantasy_data_id rotoworld_id                         sportradar_id  \
# 5870           20841        13963  0042266b-cb28-4012-bfd2-06650badad97
# 1347           14866          NaN  36521d92-2c2c-4ae4-9b60-9928c3167e30
# 3396           18157        11410  58ea6518-6fb7-4e5a-a586-7202d4c5f07e
# 6343           21260          NaN  941662f4-da41-48cf-a663-cfbd011491bb
# 3199           17960        11222  90c1756d-1f47-41b7-89fe-b113c9850bc1
# ...              ...          ...                                   ...
# 1650           15394          NaN  1954ad13-caa8-49bd-9000-a305d16b6291
# 2912           17380          NaN  2e4308b9-4ead-4fcd-9e03-32503c3db1dc
# 1195           14385         7426  5c2a0c83-e18a-43dd-bd65-704771157e42
# 3914           18740          NaN  37fb24c7-3205-4276-bbaf-b854033ff6be
# 5135           20073          NaN  6427f177-527b-435a-bcd1-27cf913f7e24
#
#      stats_id search_first_name search_last_name  birth_date
# 5870   879981            daniel            jones  1997-05-27
# 1347   465638             chris            gragg  1990-06-30
# 3396   602104           charone            peake  1992-10-16
# 6343   820627             manny          wilkins  1995-11-05
# 3199   653699           michael           thomas  1993-03-03
# ...       ...               ...              ...         ...
# 1650      NaN           cameron         marshall  1991-10-14
# 2912   870350            joshua          stangby  1990-09-24
# 1195   381806              doug           martin  1989-01-13
# 3914   297660            dobson          collins  1987-07-12
# 5135   835780             saeed        blacknall  1996-03-17
#
# [2313 rows x 12 columns]

# %%
mapper.T.sort_values('search_rank').head(30)
# Out:
#      position search_rank practice_participation birth_state  \
# 4034       RB           1                   None        None
# 4866       RB           2                   None        None
# 3164       RB           4                   None        None
# 4035       RB           5                   None        None
# 3198       RB           5                   None        None
# 4029       RB           6                   None        None
# 5850       RB           8                   None        None
# 3199       WR           8                   None        None
# 6820       RB           9                   None        None
# 4988       RB          10                   None        None
# 4046       QB          11                   None        None
# 4018       RB          11                   None        None
# 6151       RB          13                   None        None
# 3321       WR          14                   None        None
# 2133       WR          14                   None        None
# 3242       RB          15                   None        None
# 4199       RB          16                   None        None
# 4881       QB          18                   None        None
# 947        WR          18                   None        None
# 4663       RB          19                   None        None
# 1426       WR          20                   None        None
# 1466       TE          21                   None        None
# 4137       RB          23                   None        None
# 4037       WR          24                   None        None
# 4273       RB          25                   None        None
# 4217       TE          26                   None        None
# 4131       WR          26                   None        None
# 2216       WR          27                   None        None
# 1408       RB          30                   None        None
# 1689       WR          31                   None        None
#
#          search_full_name injury_status stats_id player_id  \
# 4034   christianmccaffrey          None   830517      4034
# 4866        saquonbarkley          None   883302      4866
# 3164       ezekielelliott          None   728338      3164
# 4035          alvinkamara  Questionable   750846      4035
# 3198         derrickhenry          None   732145      3198
# 4029           dalvincook          None   824080      4029
# 5850           joshjacobs          None   944416      5850
# 3199        michaelthomas          None   653699      3199
# 6820  clydeedwardshelaire          None     None      6820
# 4988            nickchubb          None   822857      4988
# 4046       patrickmahomes          None   839031      4046
# 4018             joemixon  Questionable   820727      4018
# 6151         milessanders  Questionable   924261      6151
# 3321           tyreekhill  Questionable   823156      3321
# 2133         davanteadams          None   611417      2133
# 3242          kenyandrake  Questionable   694588      3242
# 4199           aaronjones          None   741314      4199
# 4881         lamarjackson          None   877745      4881
# 947            juliojones          None   456614       947
# 4663         austinekeler          None   790004      4663
# 1426       deandrehopkins          None   560241      1426
# 1466          traviskelce          None   448240      1466
# 4137          jamesconner          None   742390      4137
# 4037          chrisgodwin          None   835127      4037
# 4273          chriscarson          None   882734      4273
# 4217         georgekittle  Questionable   733672      4217
# 4131        kennygolladay          None   697295      4131
# 2216            mikeevans          None   593587      2216
# 1408           leveonbell          None   543654      1408
# 1689          adamthielen          None   733643      1689
#
#      practice_description  status  ... weight injury_body_part first_name  \
# 4034                 None  Active  ...    205             None  Christian
# 4866                 None  Active  ...    233             None     Saquon
# 3164                 None  Active  ...    228             None    Ezekiel
# 4035                 None  Active  ...    215             None      Alvin
# 3198                 None  Active  ...    247             None    Derrick
# 4029                 None  Active  ...    210             None     Dalvin
# 5850                 None  Active  ...    220             None       Josh
# 3199                 None  Active  ...    212             None    Michael
# 6820                 None  Active  ...    207             None      Clyde
# 4988                 None  Active  ...    227             None       Nick
# 4046                 None  Active  ...    230             None    Patrick
# 4018                 None  Active  ...    220             None        Joe
# 6151                 None  Active  ...    211             None      Miles
# 3321                 None  Active  ...    185             None     Tyreek
# 2133                 None  Active  ...    215             None    Davante
# 3242                 None  Active  ...    211             None     Kenyan
# 4199                 None  Active  ...    208             None      Aaron
# 4881                 None  Active  ...    212             None      Lamar
# 947                  None  Active  ...    220             None      Julio
# 4663                 None  Active  ...    200             None     Austin
# 1426                 None  Active  ...    214             None    DeAndre
# 1466                 None  Active  ...    260             None     Travis
# 4137                 None  Active  ...    233             None      James
# 4037                 None  Active  ...    209             None      Chris
# 4273                 None  Active  ...    222             None      Chris
# 4217                 None  Active  ...    250             None     George
# 4131                 None  Active  ...    214             None      Kenny
# 2216                 None  Active  ...    231             None       Mike
# 1408                 None  Active  ...    225             None    Le'Veon
# 1689                 None  Active  ...    200             None       Adam
#
#                              sportradar_id years_exp sport search_first_name  \
# 4034  f96db0af-5e25-42d1-a07a-49b4e065b364         3   nfl         christian
# 4866  9811b753-347c-467a-b3cb-85937e71e2b9         2   nfl            saquon
# 3164  bef8b2b4-78bd-4a4d-bb5d-6b55ada9ef6a         4   nfl           ezekiel
# 4035  d9c857b2-97da-4fb8-a527-afbbb2a67413         3   nfl             alvin
# 3198  87c481c7-7414-43cc-82df-19ca0c2ae22e         4   nfl           derrick
# 4029  8960d61e-433b-41ea-a7ad-4e76be87b582         3   nfl            dalvin
# 5850  61694ab9-b099-408e-b48d-6a643dd069ec         1   nfl              josh
# 3199  90c1756d-1f47-41b7-89fe-b113c9850bc1         4   nfl           michael
# 6820  8aa01565-4481-443a-9951-642c98ded113         0   nfl             clyde
# 4988  4bd60b33-9fbf-4156-ba2b-8264ac37b418         2   nfl              nick
# 4046  11cad59d-90dd-449c-a839-dddaba4fe16c         3   nfl           patrick
# 4018  7797f36e-87e8-4282-b6d2-bdb1774fc3b3         3   nfl               joe
# 6151  ef3ceaf4-b733-4e06-a7f4-a94fc67361c1         1   nfl             miles
# 3321  01d8aee3-e1c4-4988-970a-8c0c2d08bd83         4   nfl            tyreek
# 2133  e7d6ae25-bf15-4660-8b37-c37716551de3         6   nfl           davante
# 3242  a0b93053-d349-4dd1-a840-24577102699b         4   nfl            kenyan
# 4199  27dd5b6e-ea65-4622-a6b4-460fd144407c         3   nfl             aaron
# 4881  e06a9c07-453a-4bb0-a7e9-2c3a64166dad         2   nfl             lamar
# 947   0b3217b9-ba37-4222-95cb-a7a222441e8b         9   nfl             julio
# 4663  e5b8c439-a48a-4f83-b63b-1a4d30e04cd3         3   nfl            austin
# 1426  5c48ade7-4b9a-4757-9643-87a6e3839e2b         7   nfl           deandre
# 1466  c3859e06-5f23-4302-a71b-04820a899d5f         7   nfl            travis
# 4137  28a084c0-14df-499f-bd1f-b975603626b7         3   nfl             james
# 4037  baa61bb5-f8d0-4f90-bbe2-028576b8d33d         3   nfl             chris
# 4273  0afca88b-83e7-49d6-80df-1f68b21cca9f         3   nfl             chris
# 4217  2ada91b0-036e-454f-83c3-6d939ff584a9         3   nfl            george
# 4131  659d31a3-9c62-4e3d-a0ea-b2e4967d6947         3   nfl             kenny
# 2216  c48c21d9-0ae5-478c-ad34-30a660cfa9b8         6   nfl              mike
# 1408  7735c02a-ee75-447c-86e6-6c2168500050         7   nfl            leveon
# 1689  2fa2b2da-4aa9-44b5-b27e-56876dfe2ad4         7   nfl              adam
#
#       birth_date team birth_city
# 4034  1996-06-07  CAR       None
# 4866  1997-02-09  NYG       None
# 3164  1995-07-22  DAL       None
# 4035  1995-07-25   NO       None
# 3198  1994-01-04  TEN       None
# 4029  1995-08-10  MIN       None
# 5850  1998-02-11   LV       None
# 3199  1993-03-03   NO       None
# 6820  1999-04-11   KC       None
# 4988  1995-12-27  CLE       None
# 4046  1995-09-17   KC       None
# 4018  1996-07-24  CIN       None
# 6151  1997-05-01  PHI       None
# 3321  1994-03-01   KC       None
# 2133  1992-12-24   GB       None
# 3242  1994-01-26  ARI       None
# 4199  1994-12-02   GB       None
# 4881  1997-01-07  BAL       None
# 947   1989-02-08  ATL       None
# 4663  1995-05-17  LAC       None
# 1426  1992-06-06  ARI       None
# 1466  1989-10-05   KC       None
# 4137  1995-05-05  PIT       None
# 4037  1996-02-27   TB       None
# 4273  1994-09-16  SEA       None
# 4217  1993-10-09   SF       None
# 4131  1993-11-03  DET       None
# 2216  1993-08-21   TB       None
# 1408  1992-02-18  NYJ       None
# 1689  1990-08-22  MIN       None
#
# [30 rows x 45 columns]

# %%
mapper.T[mapper.T['search_full_name'] == 'willfullerv']
# Out:
#      position search_rank practice_participation birth_state search_full_name  \
# 3157       WR          78                   None        None      willfullerv
#
#      injury_status stats_id player_id practice_description  status  ...  \
# 3157          None   749948      3157                 None  Active  ...
#
#      weight injury_body_part first_name                         sportradar_id  \
# 3157    184             None       Will  095e0c1a-0bea-4bc6-868f-e4bbe2ce6c30
#
#      years_exp sport search_first_name  birth_date team birth_city
# 3157         4   nfl              will  1994-04-16  HOU       None
#
# [1 rows x 45 columns]

# %%
mflmap = pd.read_json('mfl_id.json')
mflmap = pd.DataFrame(mflmap.iloc[0,1])
# Out:
#      position                   name     id team status
# 0        TMWR         Bills, Buffalo   0151  BUF    NaN
# 1        TMWR    Colts, Indianapolis   0152  IND    NaN
# 2        TMWR        Dolphins, Miami   0153  MIA    NaN
# 3        TMWR  Patriots, New England   0154  NEP    NaN
# 4        TMWR         Jets, New York   0155  NYJ    NaN
# ...       ...                    ...    ...  ...    ...
# 2516       WR          Fortson, Jody  15070  KCC    NaN
# 2517       DE       Carter, Ron'Dell  15071  DAL      R
# 2518       LB         Ajayi, Solomon  15072  CLE      R
# 2519       CB        Motley, Parnell  15073  TBB      R
# 2520       LB          Smith, Rashad  15074  CHI      R
#
# [2521 rows x 5 columns]

# %%
mflmap[mflmap['position'] == 'Def']
# Out:
#     position                      name    id team status
# 192      Def            Bills, Buffalo  0501  BUF    NaN
# 193      Def       Colts, Indianapolis  0502  IND    NaN
# 194      Def           Dolphins, Miami  0503  MIA    NaN
# 195      Def     Patriots, New England  0504  NEP    NaN
# 196      Def            Jets, New York  0505  NYJ    NaN
# 197      Def       Bengals, Cincinnati  0506  CIN    NaN
# 198      Def         Browns, Cleveland  0507  CLE    NaN
# 199      Def         Titans, Tennessee  0508  TEN    NaN
# 200      Def     Jaguars, Jacksonville  0509  JAC    NaN
# 201      Def      Steelers, Pittsburgh  0510  PIT    NaN
# 202      Def           Broncos, Denver  0511  DEN    NaN
# 203      Def       Chiefs, Kansas City  0512  KCC    NaN
# 204      Def        Raiders, Las Vegas  0513  LVR    NaN
# 205      Def     Chargers, Los Angeles  0514  LAC    NaN
# 206      Def         Seahawks, Seattle  0515  SEA    NaN
# 207      Def           Cowboys, Dallas  0516  DAL    NaN
# 208      Def          Giants, New York  0517  NYG    NaN
# 209      Def      Eagles, Philadelphia  0518  PHI    NaN
# 210      Def        Cardinals, Arizona  0519  ARI    NaN
# 211      Def  FootballTeam, Washington  0520  WAS    NaN
# 212      Def            Bears, Chicago  0521  CHI    NaN
# 213      Def            Lions, Detroit  0522  DET    NaN
# 214      Def        Packers, Green Bay  0523  GBP    NaN
# 215      Def        Vikings, Minnesota  0524  MIN    NaN
# 216      Def     Buccaneers, Tampa Bay  0525  TBB    NaN
# 217      Def          Falcons, Atlanta  0526  ATL    NaN
# 218      Def        Panthers, Carolina  0527  CAR    NaN
# 219      Def         Rams, Los Angeles  0528  LAR    NaN
# 220      Def       Saints, New Orleans  0529  NOS    NaN
# 221      Def      49ers, San Francisco  0530  SFO    NaN
# 222      Def         Ravens, Baltimore  0531  BAL    NaN
# 223      Def           Texans, Houston  0532  HOU    NaN

# %%
mflmap['position'].unique()
# Out:
# array(['TMWR', 'TMRB', 'TMDL', 'TMLB', 'TMDB', 'TMTE', 'Def', 'ST', 'Off',
#        'TMQB', 'TMPK', 'TMPN', 'Coach', 'PK', 'RB', 'QB', 'CB', 'LB',
#        'TE', 'WR', 'PN', 'S', 'DT', 'DE'], dtype=object)

# %%
process_proj = interactive(gm.process_projections,
                           {'manual':True},
                           projection_path='ffa_customrankings2020-0.csv',
                           idmap_path='espn_ffa_map.csv',
                           output_path='players_NEW.pkl'
                          )

update_prob = interactive(gm.create_prob_pickle,
                          {'manual':True},
                          teams=[8,10,12,14],
                          scoring=['standard','ppr','half-ppr','2qb'],
                          outputname='pick_prob_NEW.pkl',
                          mapping_path='probmap.csv'
                         )

# %% [markdown]
# # Update Projections
# fill in the fields and click "Run Interact" to process projections.

# %%
display(process_proj)
# Out:
# interactive(children=(Text(value='ffa_customrankings2020-0.csv', description='projection_path'), Text(value='e…

# %% [markdown]
# # Update Pick Probabilities
# select the closest Team number and Scoring settings, fill in the mapping path and outputname,
# then click "Run Interact". Scraping this info will take a minute.

# %%
display(update_prob)
# Out:
# interactive(children=(Dropdown(description='teams', options=(8, 10, 12, 14), value=8), Dropdown(description='s…

# %%
update_prob.children
# Out:
# (Dropdown(description='teams', index=1, options=(8, 10, 12, 14), value=10),
#  Dropdown(description='scoring', options=('standard', 'ppr', 'half-ppr', '2qb'), value='standard'),
#  Text(value='pick_prob_NEW_10_standard.pkl', description='outputname'),
#  Text(value='probmap.csv', description='mapping_path'),
#  Button(description='Run Interact', style=ButtonStyle()),
#  Output())

# %%
def start_draft(team_name,proj_path,prob_path):
    global projections
    global probabilities
    global d
    print('1 of 4: reading projections')
    projections = pd.read_pickle(proj_path)
    print('2 of 4: reading pick probabilities')
    probabilities = pd.read_pickle(prob_path)
    print('3 of 4: launching driver - this will take a minute')
    d = gm.ds.draft_monitor(team_name)
    print('4 of 4: done')

# %%
x = interactive(start_draft,
                {'manual':True},
                team_name='Team LASTNAME',
                proj_path=fixed(process_proj.children[2].value),
                prob_path=fixed(update_prob.children[2].value)
               )

# %% [markdown]
# # Launch your draft
# Fill in your espn team name and press Run Interact again. This will bring up a new firefox window that you will use for your actual draft.
#
# Use this new window to log into your espn account and navigate to your draft room.

# %%
display(x)
# Out:
# interactive(children=(Text(value='Team LASTNAME', description='team_name'), Button(description='Run Interact',…

# %% [markdown]
# If you made a typo in your team name, you will get a "'Team Whatever' is not in list" error.
# Change your team name with ```d.team_name = "correct team name here"```

# %%
d.team_name = "TEAM WHITING"

# %%
d.configure_draft()

# %%
d.myteam
# Out:
# 7

# %%
d.update()

# %% [markdown]
# Run ```d.myteam``` to make sure the number matches your first round pick.
# If it's wrong, change it with ```d.myteam = YOURPICK```

# %% [markdown]
# Run ```gm.tell_me_what_to_do()``` on your every turn.

# %%
y = d.process_update()

# %%
draft = d

# %%
draft.update()

# %%
projections[['player','picked']]
# Out:
#                   player  picked
# 0    Christian McCaffrey   False
# 1         Saquon Barkley   False
# 2        Ezekiel Elliott   False
# 3          Derrick Henry   False
# 4            Dalvin Cook   False
# ..                   ...     ...
# 481          Keke Coutee   False
# 532    Mitchell Trubisky   False
# 596       Tua Tagovailoa   False
# 603      Jacoby Brissett   False
# 605       Jameis Winston   False
#
# [282 rows x 2 columns]

# %%
picked = draft.process_update()

# %%
players = draft.filter_picks(projections)

# %%
players[['player','picked']]
# Out:
#                   player  picked
# 0    Christian McCaffrey   False
# 1         Saquon Barkley   False
# 2        Ezekiel Elliott   False
# 3          Derrick Henry   False
# 4            Dalvin Cook   False
# ..                   ...     ...
# 481          Keke Coutee   False
# 532    Mitchell Trubisky   False
# 596       Tua Tagovailoa   False
# 603      Jacoby Brissett   False
# 605       Jameis Winston   False
#
# [282 rows x 2 columns]

# %%
players = draft.map_empty_positions(players)

# %%
np1, np2 = gm.dl.next_picks(draft.pick_order,draft.myteam, draft.current_pick)

# %%
px = gm.dl.adj_probs(players,probabilities,np1,np2)

# %%
gm.dl.top_picks(px)
# Out:
#                  player team position      points      adp  picked   oc_adj_0  \
# 0   Christian McCaffrey  CAR       RB  288.361170   1.9333   False  97.344591
# 1        Saquon Barkley  NYG       RB  268.684080   2.0467   False  77.667501
# 2       Ezekiel Elliott  DAL       RB  256.357612   3.4967   False  65.341032
# 3         Derrick Henry  TEN       RB  238.102413  16.4267   False  47.085833
# 4           Dalvin Cook  MIN       RB  235.899454   7.7600   False  44.882875
# 15       Michael Thomas   NO       WR  207.062160   8.3600   False  31.167031
# 12        Lamar Jackson  BAL       QB  346.093124  42.3867   False  24.213673
# 5          Alvin Kamara   NO       RB  223.313183   4.0033   False  32.296603
# 22         Travis Kelce   KC       TE  165.734935  17.8100   False   3.125335
# 20        Davante Adams   GB       WR  194.296028  11.3533   False  18.345696
#
#       oc_adj_1
# 0   105.438968
# 1    85.761877
# 2    73.435409
# 3    55.180210
# 4    52.977252
# 15   45.492302
# 12   40.429188
# 5    40.390980
# 22   35.058494
# 20   32.726170

# %%
gm.tell_me_what_to_do(projections,probabilities,d)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-47-f09d0f80ccad> in <module>
# ----> 1 gm.tell_me_what_to_do(projections,probabilities,d)
#
# ~\aaPython\foot\footb\grandmaster\__init__.py in tell_me_what_to_do(players, prob, draft)
#       5
#       6 def tell_me_what_to_do(players,prob,draft):
# ----> 7     players = draft.filter_picks(players)
#       8     players = draft.map_empty_positions(players)
#       9     np1, np2 = dl.next_picks(draft.pick_order,draft.myteam, draft.current_pick)
#
# ~\aaPython\foot\footb\grandmaster\draft_scrape.py in filter_picks(self, df)
#     243
#     244     def filter_picks(self,df):
# --> 245         dfp = self.process_update()
#     246         df['picked'] = df['espn_id'].isin(dfp.index.astype(str))
#     247         df['round'] = df['espn_id'].map(dfp['round'])
#
# ~\aaPython\foot\footb\grandmaster\draft_scrape.py in process_update(self)
#     222
#     223     def process_update(self):
# --> 224         self.update()
#     225         dfpids = pd.DataFrame(self.pickids)
#     226         dfpids.columns = ['round','pick','espn_id','espn_name']
#
# ~\aaPython\foot\footb\grandmaster\draft_scrape.py in update(self)
#     167         """
#     168         self.get_current_pick()
# --> 169         self.pick_history()
#     170     #     current_pick = 128
#     171         cR = (self.current_pick-1) // self.teams + 1
#
# ~\aaPython\foot\footb\grandmaster\draft_scrape.py in pick_history(self)
#     139
#     140     def pick_history(self):
# --> 141         self.driver.find_element_by_xpath('/html/body/div[1]/div[1]/section/div/div[2]/main/div/div/div[3]/div[2]/div[2]/div/nav/ul/li[2]/button').click()
#     142         pass
#     143
#
# ~\.conda\envs\ffootball\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\.conda\envs\ffootball\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\.conda\envs\ffootball\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\.conda\envs\ffootball\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: Unable to locate element: /html/body/div[1]/div[1]/section/div/div[2]/main/div/div/div[3]/div[2]/div[2]/div/nav/ul/li[2]/button

# %%
projections.dtypes

# %%
p['picked']

# %%
px[['player','picked']]

# %%
gm.dl.top_picks(px)

# %% [markdown]
# Feel free to explore the package and classes while you wait for your turn to return
